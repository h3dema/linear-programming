# %% [markdown]
# # Programacao linear
#
# A programação linear é um conjunto de técnicas usadas para resolver sistemas de equações lineares e desigualdades enquanto maximiza ou minimiza alguma função linear. É importante em áreas como computação científica, economia, ciências técnicas, manufatura, transporte, militar, gerenciamento, energia e assim por diante.
#
#
# ### Exemplo de sistema de equacoes lineares
#
# Sistemas lineares são formados por duas ou mais equações lineares que possuem suas incógnitas relacionadas.
# O trabalho com equações existe devido à necessidade de encontrarmos valores desconhecidos de incógnitas. Chamamos de equação quando temos uma expressão algébrica com igualdade, e ela é classificada como linear quando o maior expoente de suas incógnitas é 1.
# De modo geral, uma equação linear pode ser descrita por:
#
# $a_1 x_1 + a_2 x_2 + a_3 x_3 \dots + a_n x_n = c$
#
# Um sistema de equacoes contem diversas equacoes lineares como no exemplo abaixo:
#
# $\begin{matrix}
# 2x_1 + x_2 = 3 \\
# -x_1 + 2x_2 > 0 \\
# 3x_1 + 4x_2 > 5 \\
# x_1 > 0 \\
# x_2 > 0
# \end{matrix}$
#
#
# ### O que é Programação Linear?
#
# Imagine que você tem um sistema de equações lineares e inequações. Tais sistemas geralmente têm muitas soluções possíveis. A programação linear é um conjunto de ferramentas matemáticas e computacionais que permite encontrar uma solução particular para esse sistema que corresponda ao máximo ou mínimo de alguma outra função linear.

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(5, 5))

f1 = lambda x: 3 - 2 * x
f2 = lambda x: x / 2
f3 = lambda x: (5 - 3 * x) / 4

# Eq.2
plt.fill([0, 100, 100, 0],[f2(0), f2(100), 100, 100], 'red', alpha=0.2)
plt.text(2, 3, "$-x_1 + 2x_2 > 0$", fontsize=16)


# Eq.3
plt.fill([0, 100, 100, 0],[f3(0), f3(100), 100, 100], 'blue', alpha=0.2)
plt.text(2, 0.5, "$3x_1 + 4x_2 > 5$", fontsize=16)


# Eq.1
plt.plot([0, 100], [f1(0), f1(100)], color="black")


plt.xlabel("$x_1$", fontsize=16)
plt.ylabel("$x_2$", fontsize=16)
plt.xlim(0, 4)
plt.ylim(0, 4)
plt.show()

# %% [markdown]
# Observamos que a solução dadas pelas inequações corresponde a área hachuda formada pela interseção das áreas em azul e vermelho.
# A primeira equação define uma reta, mostrada em preto.
# A solução corresponde a algum ponto desta reta dentro da área hachuda.

# %% [markdown]
# # Outras informações
#
# ### Pacotes
#
# Existem diversos pacotes para resolução de sistemas lineares:
#
#
# | Pacote | Descrição | Licença |
# |--------|-----------|---------|
# | [GLPK](https://www.gnu.org/software/glpk/)   | Pacote GNU para PL em larga escala, programação inteira mista (MIP) e outros problemas relacionados desenvolvido em C. | Free |
# | [scipy linprog](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linprog.html)       |  Função para resolução de problemas de PL.  Recentemente incorporou MILP | Free |
# | [lp-solve](https://lpsolve.sourceforge.net/5.5/) | É um solver baseado no método simplex revisado e no método Branch-and-bound para inteiros. | Free |
# | [CBC](https://github.com/coin-or/Cbc) | É um solver de MILP de código aberto escrito em C++. | Free |
# | [Gurobi](https://www.gurobi.com/) | state-of-the-art solver | Free trial/Proprietário |
# | [IBM ILOG CPLEX Optimizer](https://www.ibm.com/products/ilog-cplex-optimization-studio/cplex-optimizer) | Excelente programa otimizador para problemas de PL em escala muito grande. | Proprietário |
#
# ### Recursos didáticos
#
# Uma boa opcao para conhecer mais sobre programacao linear é utilizar o site [Brilliant](https://brilliant.org/wiki/linear-programming/).
#
# Um tutorial pode ser encontrado em [MIT - Optimization Methods In Management Science](https://ocw.mit.edu/courses/15-053-optimization-methods-in-management-science-spring-2013/pages/tutorials/).
#
# Existem ainda diversos livros sobre o assunto, como:
# - [Convex Optimization](https://web.stanford.edu/~boyd/cvxbook/bv_cvxbook.pdf) [pdf]
# - [Engineering Optimization: Theory and Practice](https://onlinelibrary.wiley.com/doi/book/10.1002/9781119454816)
# - [Linear Programming: Foundations and Extensions](https://link.springer.com/book/10.1007/978-1-4614-7630-6)
# - [Model Building in Mathematical Programming](https://www.wiley.com/en-us/Model+Building+in+Mathematical+Programming%2C+5th+Edition-p-9781118443330)
# - [Pesquisa Operacional Para Cursos de Engenharia](https://www.amazon.com.br/Pesquisa-Operacional-Para-Cursos-Engenharia/dp/8535248935)
